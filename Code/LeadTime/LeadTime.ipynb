# %% [markdown]
# # Lokad_Purchase Orders

# %% [raw]
# The file describes about the historical purchase data for every transactional shipment.
# ID: the SKU (Stock keeping Unit) identifier (value: 10014552/Chicago)
# Loc: the identifier of the geographical location (value: Chicago)
# Ref: the identifier of the product (value: 10014552)
# DeliveryDate: date when the good were delivered, missing values for some which I guess represent the order for which goods are not delivered (value: 22-06-16)
# Quantity: order quantity in units (value: 50)
# Received: received quantity in units (value: 50)
# NetAmount: amount paid for the purchase order (value: 165)
# Supplier: identifies the supplier who received the purchase order (value: FHL)
# PoNumber: unique identifier for purchase order (value: PONumber)
# Date: date when the purchase order was placed (value: 20-04-16)
# Currency: code for the currency (value: USD)

# %% [markdown]
# ### Reading of CSV file

# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

purchase_data = pd.read_csv('Lokad_PurchaseOrders.csv')
purchase_data
# Out:
#       Unnamed: 0                    Id          Loc       Ref DeliveryDate  \
# 0              0  15641711/Los Angeles  Los Angeles  15641711   2016-06-22
# 1              1  15641711/Los Angeles  Los Angeles  15641711   2016-07-29
# 2              2  16075571/Los Angeles  Los Angeles  16075571   2016-06-22
# 3              3  16075571/Los Angeles  Los Angeles  16075571   2016-07-29
# 4              4  16075571/Los Angeles  Los Angeles  16075571   2001-01-01
# 5              5  14759689/Los Angeles  Los Angeles  14759689   2001-01-01
# 6              6  14095459/Los Angeles  Los Angeles  14095459   2001-01-01
# 7              7  15586718/Los Angeles  Los Angeles  15586718   2001-01-01
# 8              8  10095232/Los Angeles  Los Angeles  10095232   2015-05-08
# 9              9  10095232/Los Angeles  Los Angeles  10095232   2016-06-21
# 10            10  10095232/Los Angeles  Los Angeles  10095232   2016-06-20
# ...

# %%
purchase_data.dtypes
# Out:
# Unnamed: 0         int64
# Id                object
# Loc               object
# Ref                int64
# DeliveryDate      object
# Quantity           int64
# Received           int64
# NetAmount        float64
# Supplier          object
# PONumber          object
# Date              object
# Currency          object
# reorder_delay     object
# 0_x               object
# 0_y               object
# dtype: object

# %% [markdown]
# ### Supply Delay

# %%
purchase_data['Date'] = pd.to_datetime(purchase_data['Date'])
purchase_data['DeliveryDate'] = pd.to_datetime(purchase_data['DeliveryDate'])

purchase_data.dtypes
# Out:
# Unnamed: 0                int64
# Id                       object
# Loc                      object
# Ref                       int64
# DeliveryDate     datetime64[ns]
# Quantity                  int64
# Received                  int64
# NetAmount               float64
# Supplier                 object
# PONumber                 object
# Date             datetime64[ns]
# Currency                 object
# reorder_delay            object
# 0_x                      object
# 0_y                      object
# dtype: object

# %% [markdown]
# ### Lead_Time = SupplyDelay + Constant(Reorder delay)
# ### Reorder delay is kept constant as it depends on the bussiness agremment with the supplier

# %%
## supply_delay: is the delay in the delivery of the consignment(calculated in days)
## For the supply delay calculation we are going to calculate the difference between the Date column of Lokad_PurchaseOrders and 
## DeliveryDate of the same 
## Date: defines the date when the order was place
## DeliveryDate: defines when the order was delivered to the store.

import math

supply_delay = purchase_data['DeliveryDate'] - purchase_data['Date']

print("Supply Delay: {}\n", format(abs(supply_delay)))
# Out:
# Supply Delay: {}
#  0        63 days
# 1         3 days
# 2        63 days
# 3         3 days
# 4      5714 days
# 5      5714 days
# 6      5696 days
# 7      5696 days
# 8        19 days
# 9       209 days
# 10      252 days
# 11     5576 days
# 12      209 days
# 13     5714 days
# 14       17 days
# 15     5576 days
# 16     5415 days
# 17      107 days
# 18      107 days
# 19     5415 days
# 20      209 days
# 21     5708 days
# 22     5415 days
# 23      209 days
# 24     5708 days
# 25     5721 days
# 26       19 days
# 27      209 days
# 28      149 days
# 29      107 days
#           ...
# 1046    143 days
# 1047   5749 days
# 1048    132 days
# 1049    132 days
# 1050   5736 days
# 1051     20 days
# 1052     50 days
# 1053     20 days
# 1054     42 days
# 1055     49 days
# 1056    203 days
# 1057    143 days
# 1058     66 days
# 1059    203 days
# 1060    143 days
# 1061     66 days
# 1062   5415 days
# 1063    256 days
# 1064    132 days
# 1065     84 days
# ...

# %% [markdown]
# ### Storing supply delay

# %%
delay = pd.DataFrame(supply_delay)
purchase_data = purchase_data.merge(delay, left_index = True, right_index = True)
purchase_data.to_csv('Lokad_PurchaseOrders.csv')

purchase_data
# Out:
#       Unnamed: 0                    Id          Loc       Ref DeliveryDate  \
# 0              0  15641711/Los Angeles  Los Angeles  15641711   2016-06-22
# 1              1  15641711/Los Angeles  Los Angeles  15641711   2016-07-29
# 2              2  16075571/Los Angeles  Los Angeles  16075571   2016-06-22
# 3              3  16075571/Los Angeles  Los Angeles  16075571   2016-07-29
# 4              4  16075571/Los Angeles  Los Angeles  16075571   2001-01-01
# 5              5  14759689/Los Angeles  Los Angeles  14759689   2001-01-01
# 6              6  14095459/Los Angeles  Los Angeles  14095459   2001-01-01
# 7              7  15586718/Los Angeles  Los Angeles  15586718   2001-01-01
# 8              8  10095232/Los Angeles  Los Angeles  10095232   2015-05-08
# 9              9  10095232/Los Angeles  Los Angeles  10095232   2016-06-21
# 10            10  10095232/Los Angeles  Los Angeles  10095232   2016-06-20
# ...

# %% [markdown]
# ## Reordering Delay (Not required)

# %%
# unique_ref = purchase_data.Ref
# date = purchase_data.Date

# %%
# import math
# for i in range (len(unique_ref)):
    # print(unique_ref[i])
    #if unique_ref[i + 1] == unique_ref[i]:
        #print(unique_ref[i])

# %%
# purchase_data['reorder_delay'] = purchase_data.sort_values(['Ref','Date']).groupby('Ref')['Date'].diff()
# print (purchase_data['reorder_delay'])

# %% [markdown]
# ## Avreage Lead Time

# %%
## The average lead time calculates the av_lead time for the paticular products for all its instances

# %%
purchase_data.groupby('Ref', as_index = True).mean()
# Out:
#           Unnamed: 0    Quantity    Received    NetAmount
# Ref
# 9952426   734.500000    9.000000    9.000000   579.419976
# 10014552  541.666667   13.666667   12.222222   100.723332
# 10095232  312.461538  215.384615  215.384615  5746.461603
# 10099950  438.125000   28.750000   11.250000   950.475040
# 10132892  784.000000   26.000000   21.600000  1205.880029
# 10136626  775.142857  121.428571   92.857143  4857.142857
# 10210677  494.000000    9.333333    6.000000   594.066681
# 10255812  477.142857  752.142857  728.571429   752.142857
# 10422793  286.600000   44.200000   44.200000   585.207991
# 10592438  513.250000   24.500000   22.000000    84.280001
# 10595489  408.950000   29.000000   24.300000  1097.360006
# 10678449  413.444444   27.111111   11.111111   896.293371
# 10764226  515.444444   35.555556   35.555556   617.600028
# 11045096  739.600000   19.400000   11.200000   716.247965
# 11097836  636.642857   26.857143   20.000000   670.354262
# ...
